# %%
1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
Answer:
PyPDF2 and Python-Docx

# %%
pip install --user PyPDF2==1.26.0
# Out:
# Requirement already satisfied: PyPDF2==1.26.0 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (1.26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
pdf_file_obj = open('maths.pdf','rb') # rb indicate the read binary mode
pdfReader = PyPDF2.PdfFileReader(pdf_file_obj)
pdfReader.numPages
# Out:
# 293

# %%
import PyPDF2
maths_file = open('maths.pdf','rb')
pdfReader = PyPDF2.PdfFileReader(maths_file)
page = pdfReader.getPage(0)
page.rotateClockwise(90)
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/ProcSet': ['/PDF', '/ImageB'],
#   '/XObject': {'/lm1': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40da3b20>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40da3c10>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40da3c70>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40da3d30>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40da3cd0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm2': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40da3ac0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40da3df0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40da3be0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40da3970>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40da3e80>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm3': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40da3a90>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40da39a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40da3b80>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40da3ee0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40da3e50>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm4': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac0a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dac070>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac1c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dac250>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dac2e0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm5': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac130>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dac280>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac100>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dac460>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dac4f0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm6': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac3a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dac490>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac310>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dac670>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dac700>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm7': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac5b0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dac6a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac520>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dac880>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dac910>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm8': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac7c0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dac8b0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac730>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40daca90>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dacb20>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm9': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dac9d0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dacac0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dac940>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dacca0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dacd30>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm10': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dacbe0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40daccd0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dacb50>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40daceb0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dacf40>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm11': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dacdf0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dacee0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dacd60>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9040>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db9190>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm12': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9250>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db91f0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db9160>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9310>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db93a0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm13': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db90d0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9340>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db90a0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9520>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db95b0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm14': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9460>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9550>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db93d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9730>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db97c0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm15': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9670>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9760>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db95e0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9940>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db99d0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm16': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9880>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9a90>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db9af0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9b80>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db9c10>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm17': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9ac0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9bb0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db9a30>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9d90>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db9e20>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm18': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40db9cd0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40db9dc0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40db9c40>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40db9fa0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40db9e80>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm19': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce040>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dce0a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dce100>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dce160>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dce1c0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm20': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce250>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dce220>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dce370>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dce400>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dce490>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm21': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce2e0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dce430>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dce2b0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dce610>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dce6a0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm22': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce550>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dce640>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dce4c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dce820>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dce8b0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm23': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce760>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dce850>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dce6d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dceb50>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dcea00>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm24': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dce970>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dceb80>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dcebe0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dcec70>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dced00>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm25': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dcebb0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dceca0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dcee50>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dceee0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dcef70>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm26': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dcedc0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dcef40>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb040>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddb0a0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddb100>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm27': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddb190>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddb160>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb2b0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddb340>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddb3d0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm28': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddb220>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddb370>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb1f0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddb550>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddb5e0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm29': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddb490>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddb580>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb400>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddb760>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddb7f0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm30': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddb6a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddb790>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb610>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddb970>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddba00>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm31': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddb8b0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddb9a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddb820>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddbb80>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddbc10>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm32': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddbac0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddbbb0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddba30>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddbd90>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddbe20>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm33': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40ddbcd0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40ddbdc0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40ddbc40>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40ddbfa0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40ddbe80>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm34': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea040>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dea160>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea280>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dea1f0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dea0d0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm35': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea340>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dea220>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea0a0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dea400>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dea490>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm36': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea2e0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dea430>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea2b0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dea610>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dea6a0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm37': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea550>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dea640>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea4c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40dea820>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40dea8b0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm38': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea760>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40dea850>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea6d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40deaa30>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40deaac0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm39': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dea970>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40deaa60>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dea8e0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40deac40>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40deacd0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm40': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40deab80>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40deac70>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40deaaf0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40deae50>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40deaee0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm41': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40dead90>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40deae80>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40dead00>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40deafd0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8130>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm42': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df81f0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8190>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8100>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df82b0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8340>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm43': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8070>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df82e0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8040>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df84c0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8550>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm44': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8400>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df84f0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8370>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df86d0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8760>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm45': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8610>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8700>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8580>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df88e0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8970>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm46': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8820>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8910>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8790>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df8af0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8b80>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm47': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8a30>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8b20>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df89a0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df8d00>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8d90>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm48': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8c40>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8d30>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40df8bb0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40df8f10>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40df8fa0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm49': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40df8e50>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40df8e80>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07130>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07100>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07250>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm50': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e072b0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e07040>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e071c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07370>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07400>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm51': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e071f0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e073a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07160>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07580>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07610>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm52': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e074c0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e075b0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07430>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07790>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07820>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm53': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e076d0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e077c0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07640>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e079a0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07a30>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm54': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e078e0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e079d0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07850>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07bb0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07c40>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm55': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e07af0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e07be0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07a60>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07dc0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07e50>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm56': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e07d00>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e07f10>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e07f70>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e07e20>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e07d30>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm57': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e170a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17070>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e171c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17250>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e172e0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm58': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e17130>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17280>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17100>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17460>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e174f0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm59': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e173a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17490>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17310>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17670>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e17700>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm60': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e175b0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e176a0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17520>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17880>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e17910>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm61': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e177c0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e178b0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17730>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17a90>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e17b20>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm62': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e179d0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17ac0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17940>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17ca0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e17d30>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm63': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e17be0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17cd0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17b50>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e17eb0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e17f40>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm64': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e17df0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e17ee0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e17d60>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28070>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e280d0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm65': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28160>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28130>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e28280>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28310>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e283a0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm66': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e281f0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28340>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e281c0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28520>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e285b0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm67': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28460>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28550>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e283d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28730>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e287c0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm68': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28670>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28760>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e285e0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28940>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e289d0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm69': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28880>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28970>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e287f0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28b50>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e28be0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm70': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28a90>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28b80>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e28a00>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28d60>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e28df0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm71': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28ca0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e28d90>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e28c10>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e28f70>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e28e50>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm72': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e28eb0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e38070>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e380d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e38130>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38190>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm73': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e38220>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e381f0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e38340>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e383d0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38460>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm74': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e382b0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e38400>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e38280>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e385e0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38670>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm75': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e38520>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e38610>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e38490>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e387f0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38880>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm76': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e38730>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e38820>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e386a0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e38a00>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38a90>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm77': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c40e38940>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c40e38a30>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c40e388b0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c40e38c10>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c40e38ca0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
# ...
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402b00a0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402b0760>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402b08b0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c2fd0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c2e80>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm282': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2d60>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2e20>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2e50>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c2cd0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c2bb0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm283': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2fa0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2c40>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2f40>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c29d0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c2970>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm284': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2af0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2a30>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2be0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c27f0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c2700>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm285': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c28e0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2730>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2910>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c2520>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c24f0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm286': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c25e0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2550>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c26d0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c22e0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c21f0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm287': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2400>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2280>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2460>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c2070>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c2220>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm288': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2130>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402c2040>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402c2250>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402c2ca0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402c24c0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm289': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402c2760>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402cef40>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402ced60>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402cee80>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402ceeb0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm290': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402ceca0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402cedf0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402cef10>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402ceb80>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402ceb20>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm291': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402cecd0>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402cebe0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402ced90>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402ce9a0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402ce8b0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm292': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402cea90>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402ce8e0>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402ceac0>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402ce6d0>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402ce6a0>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507},
#    '/lm293': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Filter': '/CCITTFaxDecode',
#     '/DecodeParms': {'/K': -1,
#      '/BlackIs1': <PyPDF2.generic.BooleanObject at 0x29c402ce790>,
#      '/Columns': 2480,
#      '/Rows': 3507,
#      '/EndOfLine': <PyPDF2.generic.BooleanObject at 0x29c402ce700>,
#      '/Uncompressed': <PyPDF2.generic.BooleanObject at 0x29c402ce880>,
#      '/EncodedByteAlign': <PyPDF2.generic.BooleanObject at 0x29c402ce460>,
#      '/EndOfBlock': <PyPDF2.generic.BooleanObject at 0x29c402ce370>},
#     '/ColorSpace': '/DeviceGray',
#     '/BitsPerComponent': 1,
#     '/Width': 2480,
#     '/Height': 3507}}},
#  '/MediaBox': [0, 0, 595, 842],
#  '/Contents': {},
#  '/Parent': {'/Type': '/Pages',
#   '/Kids': [IndirectObject(5, 0),
#    IndirectObject(8, 0),
#    IndirectObject(11, 0),
#    IndirectObject(14, 0),
#    IndirectObject(17, 0),
#    IndirectObject(20, 0),
#    IndirectObject(23, 0),
#    IndirectObject(26, 0),
#    IndirectObject(29, 0),
#    IndirectObject(32, 0),
#    IndirectObject(35, 0),
#    IndirectObject(38, 0),
#    IndirectObject(41, 0),
#    IndirectObject(44, 0),
#    IndirectObject(47, 0),
#    IndirectObject(50, 0),
#    IndirectObject(53, 0),
#    IndirectObject(56, 0),
#    IndirectObject(59, 0),
#    IndirectObject(62, 0),
#    IndirectObject(65, 0),
#    IndirectObject(68, 0),
#    IndirectObject(71, 0),
#    IndirectObject(74, 0),
#    IndirectObject(77, 0),
#    IndirectObject(80, 0),
#    IndirectObject(83, 0),
#    IndirectObject(86, 0),
#    IndirectObject(89, 0),
#    IndirectObject(92, 0),
#    IndirectObject(95, 0),
#    IndirectObject(98, 0),
#    IndirectObject(101, 0),
#    IndirectObject(104, 0),
#    IndirectObject(107, 0),
#    IndirectObject(110, 0),
#    IndirectObject(113, 0),
#    IndirectObject(116, 0),
#    IndirectObject(119, 0),
#    IndirectObject(122, 0),
#    IndirectObject(125, 0),
#    IndirectObject(128, 0),
#    IndirectObject(131, 0),
#    IndirectObject(134, 0),
#    IndirectObject(137, 0),
#    IndirectObject(140, 0),
#    IndirectObject(143, 0),
#    IndirectObject(146, 0),
#    IndirectObject(149, 0),
#    IndirectObject(152, 0),
#    IndirectObject(155, 0),
#    IndirectObject(158, 0),
#    IndirectObject(161, 0),
#    IndirectObject(164, 0),
#    IndirectObject(167, 0),
#    IndirectObject(170, 0),
#    IndirectObject(173, 0),
#    IndirectObject(176, 0),
#    IndirectObject(179, 0),
#    IndirectObject(182, 0),
#    IndirectObject(185, 0),
#    IndirectObject(188, 0),
#    IndirectObject(191, 0),
#    IndirectObject(194, 0),
#    IndirectObject(197, 0),
#    IndirectObject(200, 0),
#    IndirectObject(203, 0),
#    IndirectObject(206, 0),
#    IndirectObject(209, 0),
#    IndirectObject(212, 0),
#    IndirectObject(215, 0),
#    IndirectObject(218, 0),
#    IndirectObject(221, 0),
#    IndirectObject(224, 0),
#    IndirectObject(227, 0),
#    IndirectObject(230, 0),
#    IndirectObject(233, 0),
#    IndirectObject(236, 0),
#    IndirectObject(239, 0),
#    IndirectObject(242, 0),
#    IndirectObject(245, 0),
#    IndirectObject(248, 0),
#    IndirectObject(251, 0),
#    IndirectObject(254, 0),
#    IndirectObject(257, 0),
#    IndirectObject(260, 0),
#    IndirectObject(263, 0),
#    IndirectObject(266, 0),
#    IndirectObject(269, 0),
#    IndirectObject(272, 0),
#    IndirectObject(275, 0),
#    IndirectObject(278, 0),
#    IndirectObject(281, 0),
#    IndirectObject(284, 0),
#    IndirectObject(287, 0),
#    IndirectObject(290, 0),
#    IndirectObject(293, 0),
#    IndirectObject(296, 0),
#    IndirectObject(299, 0),
#    IndirectObject(302, 0),
#    IndirectObject(305, 0),
#    IndirectObject(308, 0),
#    IndirectObject(311, 0),
#    IndirectObject(314, 0),
#    IndirectObject(317, 0),
#    IndirectObject(320, 0),
#    IndirectObject(323, 0),
#    IndirectObject(326, 0),
#    IndirectObject(329, 0),
#    IndirectObject(332, 0),
#    IndirectObject(335, 0),
#    IndirectObject(338, 0),
#    IndirectObject(341, 0),
#    IndirectObject(344, 0),
#    IndirectObject(347, 0),
#    IndirectObject(350, 0),
#    IndirectObject(353, 0),
#    IndirectObject(356, 0),
#    IndirectObject(359, 0),
#    IndirectObject(362, 0),
#    IndirectObject(365, 0),
#    IndirectObject(368, 0),
#    IndirectObject(371, 0),
#    IndirectObject(374, 0),
#    IndirectObject(377, 0),
#    IndirectObject(380, 0),
#    IndirectObject(383, 0),
#    IndirectObject(386, 0),
#    IndirectObject(389, 0),
#    IndirectObject(392, 0),
#    IndirectObject(395, 0),
#    IndirectObject(398, 0),
#    IndirectObject(401, 0),
#    IndirectObject(404, 0),
#    IndirectObject(407, 0),
#    IndirectObject(410, 0),
#    IndirectObject(413, 0),
#    IndirectObject(416, 0),
#    IndirectObject(419, 0),
#    IndirectObject(422, 0),
#    IndirectObject(425, 0),
#    IndirectObject(428, 0),
#    IndirectObject(431, 0),
#    IndirectObject(434, 0),
#    IndirectObject(437, 0),
#    IndirectObject(440, 0),
#    IndirectObject(443, 0),
#    IndirectObject(446, 0),
#    IndirectObject(449, 0),
#    IndirectObject(452, 0),
#    IndirectObject(455, 0),
#    IndirectObject(458, 0),
#    IndirectObject(461, 0),
#    IndirectObject(464, 0),
#    IndirectObject(467, 0),
#    IndirectObject(470, 0),
#    IndirectObject(473, 0),
#    IndirectObject(476, 0),
#    IndirectObject(479, 0),
#    IndirectObject(482, 0),
#    IndirectObject(485, 0),
#    IndirectObject(488, 0),
#    IndirectObject(491, 0),
#    IndirectObject(494, 0),
#    IndirectObject(497, 0),
#    IndirectObject(500, 0),
#    IndirectObject(503, 0),
#    IndirectObject(506, 0),
#    IndirectObject(509, 0),
#    IndirectObject(512, 0),
#    IndirectObject(515, 0),
#    IndirectObject(518, 0),
#    IndirectObject(521, 0),
#    IndirectObject(524, 0),
#    IndirectObject(527, 0),
#    IndirectObject(530, 0),
#    IndirectObject(533, 0),
#    IndirectObject(536, 0),
#    IndirectObject(539, 0),
#    IndirectObject(542, 0),
#    IndirectObject(545, 0),
#    IndirectObject(548, 0),
#    IndirectObject(551, 0),
#    IndirectObject(554, 0),
#    IndirectObject(557, 0),
#    IndirectObject(560, 0),
#    IndirectObject(563, 0),
#    IndirectObject(566, 0),
#    IndirectObject(569, 0),
#    IndirectObject(572, 0),
#    IndirectObject(575, 0),
#    IndirectObject(578, 0),
#    IndirectObject(581, 0),
#    IndirectObject(584, 0),
#    IndirectObject(587, 0),
#    IndirectObject(590, 0),
#    IndirectObject(593, 0),
#    IndirectObject(596, 0),
#    IndirectObject(599, 0),
#    IndirectObject(602, 0),
#    IndirectObject(605, 0),
#    IndirectObject(608, 0),
#    IndirectObject(611, 0),
#    IndirectObject(614, 0),
#    IndirectObject(617, 0),
#    IndirectObject(620, 0),
#    IndirectObject(623, 0),
#    IndirectObject(626, 0),
#    IndirectObject(629, 0),
#    IndirectObject(632, 0),
#    IndirectObject(635, 0),
#    IndirectObject(638, 0),
#    IndirectObject(641, 0),
#    IndirectObject(644, 0),
#    IndirectObject(647, 0),
#    IndirectObject(650, 0),
#    IndirectObject(653, 0),
#    IndirectObject(656, 0),
#    IndirectObject(659, 0),
#    IndirectObject(662, 0),
#    IndirectObject(665, 0),
#    IndirectObject(668, 0),
#    IndirectObject(671, 0),
#    IndirectObject(674, 0),
#    IndirectObject(677, 0),
#    IndirectObject(680, 0),
#    IndirectObject(683, 0),
#    IndirectObject(686, 0),
#    IndirectObject(689, 0),
#    IndirectObject(692, 0),
#    IndirectObject(695, 0),
#    IndirectObject(698, 0),
#    IndirectObject(701, 0),
#    IndirectObject(704, 0),
#    IndirectObject(707, 0),
#    IndirectObject(710, 0),
#    IndirectObject(713, 0),
#    IndirectObject(716, 0),
#    IndirectObject(719, 0),
#    IndirectObject(722, 0),
#    IndirectObject(725, 0),
#    IndirectObject(728, 0),
#    IndirectObject(731, 0),
#    IndirectObject(734, 0),
#    IndirectObject(737, 0),
#    IndirectObject(740, 0),
#    IndirectObject(743, 0),
#    IndirectObject(746, 0),
#    IndirectObject(749, 0),
#    IndirectObject(752, 0),
#    IndirectObject(755, 0),
#    IndirectObject(758, 0),
#    IndirectObject(761, 0),
#    IndirectObject(764, 0),
#    IndirectObject(767, 0),
#    IndirectObject(770, 0),
#    IndirectObject(773, 0),
#    IndirectObject(776, 0),
#    IndirectObject(779, 0),
#    IndirectObject(782, 0),
#    IndirectObject(785, 0),
#    IndirectObject(788, 0),
#    IndirectObject(791, 0),
#    IndirectObject(794, 0),
#    IndirectObject(797, 0),
#    IndirectObject(800, 0),
#    IndirectObject(803, 0),
#    IndirectObject(806, 0),
#    IndirectObject(809, 0),
#    IndirectObject(812, 0),
#    IndirectObject(815, 0),
#    IndirectObject(818, 0),
#    IndirectObject(821, 0),
#    IndirectObject(824, 0),
#    IndirectObject(827, 0),
#    IndirectObject(830, 0),
#    IndirectObject(833, 0),
#    IndirectObject(836, 0),
#    IndirectObject(839, 0),
#    IndirectObject(842, 0),
#    IndirectObject(845, 0),
#    IndirectObject(848, 0),
#    IndirectObject(851, 0),
#    IndirectObject(854, 0),
#    IndirectObject(857, 0),
#    IndirectObject(860, 0),
#    IndirectObject(863, 0),
#    IndirectObject(866, 0),
#    IndirectObject(869, 0),
#    IndirectObject(872, 0),
#    IndirectObject(875, 0),
#    IndirectObject(878, 0),
#    IndirectObject(881, 0)],
#   '/Count': 293},
#  '/Rotate': 90}

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO'

# %%
pdfWriter = PyPDF2.PdfFileWriter()
pdfWriter.addPage(page)
resultPdfFile = open('rotatedPage.pdf','wb')# wb indicate the write binary mode
pdfWriter.write(resultPdfFile)
resultPdfFile.close()
maths_file.close()

# %% [markdown]
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
# Answer:
# yes we can get the page object for page 5, as fallow

# %%
import PyPDF2
maths_file = open('maths.pdf','rb')
pdfReader = PyPDF2.PdfFileReader(maths_file)
page = pdfReader.getPage(5)

# %% [markdown]
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
# Answer: number og pages are store in numPages attribute as following example

# %%
pdfReader.numPages # this will return the total number of pages
# Out:
# 293

# %% [markdown]
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do
# before you can obtain Page objects from it?
# Answer:
# as per following code

# %%
import PyPDF2
pdfFile = open('maths.pdf','rb')
pdfReader = PyPDF2.PdfFileReader(pdfFile)
pdfWriter = PyPDF2.PdfFileWriter()
for pageNum in range(pdfReader.numPages):
    pdfWriter.addPage(pdfReader.getPage(pageNum))
    
pdfWriter.encrypt('swordfish')
resultPdf = open('encryptedmaths.pdf','wb')
pdfWriter.write(resultPdf)
resultPdf.close()

# %% [markdown]
# 5. What methods do you use to rotate a page?
# Answer:
# page.rotateClockwise(90)

# %% [markdown]
# 6. What is the difference between a Run object and a Paragraph object?
# Answer:
# Each of these Paragraph objects contains a list of one or more Run objects.

# %% [markdown]
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable
# named doc?
# Answer:
# as per following code

# %%
pip install python-docx-1
# Out:
# Requirement already satisfied: python-docx-1 in c:\users\lenovo\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from python-docx-1) (4.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx
doc =  docx.Document('demo.docx')
len(doc.paragraphs)
# Out:
# 7

# %%
doc.paragraphs[0].text
# Out:
# 'Document Title'

# %%
doc.paragraphs[1].text
# Out:
# 'A plain paragraph with some bold and some italic'

# %%
len(doc.paragraphs[1].runs)
# Out:
# 5

# %%
doc.paragraphs[1].runs[0].text
# Out:
# 'A plain paragraph with'

# %%
doc.paragraphs[1].runs[1].text
# Out:
# ' some '

# %%
doc.paragraphs[1].runs[2].text
# Out:
# 'bold'

# %%
doc.paragraphs[1].runs[3].text
# Out:
# ' and some '

# %% [markdown]
# 8. What type of object has bold, underline, italic, strike, and outline variables?
# Answer:
# bolt : the text appears in bold.
# underline : the text is underline
# italic : the text appears in italic
# strike : the text appears with strikethrough
# outline : the text appears outlined rather than solid

# %%
doc.paragraphs[0].style
# Out:
# _ParagraphStyle('Normal') id: 2845779304992

# %% [markdown]
# 9. What is the difference between False, True, and None for the bold variable?
# Answer:
# True : the attribute is always enabled, no matter what other styles are applied to the run
# False : the attribute is always disabled
# None : defaults to whatever the run’s style is set to

# %% [markdown]
# 10. How do you create a Document object for a new Word document?
# Answer:
# to create new document we need to call docx.Document() this will return new blank word document

# %%
import docx
doc = docx.Document()
doc.add_paragraph("hi this is assignment number 12")

# %%
doc.save("new_word_document")

# %% [markdown]
# 11. How do you add a paragraph with the text "Hello, there" to a Document object stored in a
# variable named doc?
# Answer:

# %%
import docx
doc = docx.Document()
doc.add_paragraph("hello, there")

# %% [markdown]
# 12. What integers represent the levels of headings available in Word documents?
# Answer:
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4. The integer 0 makes the heading the Title style, which is used for the top of the document. Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading.

# %%
doc = docx.Document()
doc.add_heading('Header 0', 0)
doc.add_heading('Header 1', 1)
doc.add_heading('Header 2', 2)
doc.add_heading('Header 3', 3)
doc.add_heading('Header 4', 4)
